# %%
import pandas as pd
import pint
import pint_pandas

# %%
df = pd.read_pickle("../flatten/processed-data/20251023-s288c-annotated-PPI-net.pkl")

# %%
list(df.columns)
# Out:
# ['node',
#  '_wkshell',
#  'degree_centrality',
#  'betweenness_centrality',
#  'eigenvector_centrality',
#  'closeness_centrality',
#  'load_centrality',
#  'pagerank',
#  'information_centrality',
#  'CentralityCosDist_rank',
#  'CentralityCosDist_similarity_score',
#  'has_verified_sequence',
#  'sequence',
#  'UniProtKB-AC',
#  'DeepTMHMM_trimmed_sequence',
#  'DeepTMHMM_class',
#  'cleavage_site_start',
#  'signalP_trimmed_sequence',
#  'ProteinName',
#  'GO_terms',
#  'GO_terms_human_readable',
#  'localization_keywords',
#  'parsed_functions',
#  'parsed_PTMs',
#  'ptm_bronze',
#  'ptm_gold',
#  'ptm_silver',
#  'IDR_count',
#  'IDR_sequences',
#  'IDR_ranges',
#  'N_aa_disordered',
#  'disorder_fraction',
#  'is_disordered_0.05',
#  'is_disordered_0.10',
#  'is_disordered_0.15',
#  'is_disordered_0.20',
#  'is_disordered_0.25',
#  'is_disordered_0.30',
#  'is_disordered_0.35',
#  'is_disordered_0.40',
#  'is_disordered_0.45',
#  'is_disordered_0.50',
#  'is_disordered_0.55',
# ...

# %%
df["final_sequence"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3927 entries, 0 to 3926
# Series name: final_sequence
# Non-Null Count  Dtype
# --------------  -----
# 3873 non-null   object
# dtypes: object(1)
# memory usage: 30.8+ KB

# %%
df["signalP_trimmed_sequence"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3927 entries, 0 to 3926
# Series name: signalP_trimmed_sequence
# Non-Null Count  Dtype
# --------------  -----
# 3876 non-null   object
# dtypes: object(1)
# memory usage: 30.8+ KB

# %%
for index, row in df.iterrows():
    print(index, row["node"], row["meltome-id"], row["meltome-stability-class"])
# Out:
# 0 YKL063C nan nan
# 1 YDL223C Q07653_HBT1 medium
# 2 YPL036W nan nan
# 3 YPL050C nan nan
# 4 YJR148W P47176_BAT2 medium
# 5 YHR208W P38891_BAT1 medium
# 6 YBR035C P38075_PDX3 medium
# 7 YPR008W Q12753_HAA1 non-melter
# 8 YKL024C P15700_URA6 medium
# 9 YBR286W P37302_APE3 medium
# 10 YLR420W P20051_URA4 medium
# 11 YKR066C P00431_CCP1 medium
# 12 YNL117W nan nan
# 13 YNL015W P0CT04_PBI2 non-melter
# 14 YOR285W Q12305_RDL1 stable
# 15 YOR239W Q08641_ABP140 medium
# 16 YJL055W P47044_YJL055W medium
# 17 YJL066C P40364_MPM1 medium
# 18 YGR027W-A;YGR038C-A;YJR026W;YLR227W-A;YML040W nan nan
# 19 YGL087C P53152_MMS2 medium
# 20 YNL134C P53912_YNL134C medium
# 21 YNR034W-A Q3E841_YNR034W-A medium
# 22 YPL111W P00812_CAR1 medium
# 23 YIR037W P40581_HYR1 medium
# 24 YML022W P49435_APT1 medium
# 25 YNL104C P06208_LEU4 medium
# 26 YEL060C P09232_PRB1 medium
# 27 YOR168W P13188_GLN4 medium
# 28 YER175C P32643_TMT1 medium
# 29 YEL071W P39976_DLD3 medium
# 30 YBR222C P38137_PCS60 medium
# ...
