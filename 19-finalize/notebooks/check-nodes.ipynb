# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.3

# %%
import pandas as pd
import pint
import pint_pandas
import numpy as np
import matplotlib.pyplot as plt

# %%
pkl_path = "../../18-entanglement/processed-data/union-athaliana-step18.pkl"

# %%
nodes = pd.read_pickle(pkl_path)

# %%
nodes.to_csv("union-athaliana-step18.csv")

# %%
junk = list(nodes.columns)
for j in junk:
    print (j)
# Out:
# node
# _wkshell
# degree_centrality
# betweenness_centrality
# eigenvector_centrality
# closeness_centrality
# load_centrality
# pagerank
# information_centrality
# has_verified_sequence
# sequence
# tair12_isoform_id
# tair12_sequence_length
# UniProtKB-AC
# uniprot_best_candidate_accession
# UniProtKB-AC_candidates
# uniprot_candidate_count
# uniprot_candidate_count_with_sequence
# uniprot_exact_sequence_match
# uniprot_best_sequence_identity
# uniprot_match_status
# uniprot_best_sequence_length
# uniprot_best_reviewed
# DeepTMHMM_protein_id
# DeepTMHMM_trimmed_sequence
# DeepTMHMM_class
# cleavage_site_start
# signalP_trimmed_sequence
# ProteinName
# GO_terms
# GO_terms_human_readable
# localization_keywords
# parsed_functions
# parsed_PTMs
# IDR_count
# IDR_sequences
# IDR_ranges
# N_aa_disordered
# disorder_fraction
# is_disordered_0.05
# is_disordered_0.10
# is_disordered_0.15
# is_disordered_0.20
# is_disordered_0.25
# is_disordered_0.30
# is_disordered_0.35
# ...
