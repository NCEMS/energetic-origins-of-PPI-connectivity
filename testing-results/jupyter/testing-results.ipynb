# %%
import pandas as pd
import pint
import pint_pandas

# %%
data2 = pd.read_csv("../../2-sequence-parsing/processed-data/0-s288c-nodes-centrality-seqs-DeepTMHMM-SignalP.csv")

# %%
data2.columns
# Out:
# Index(['node', '_wkshell', 'degree_centrality', 'betweenness_centrality',
#        'eigenvector_centrality', 'closeness_centrality', 'load_centrality',
#        'pagerank', 'information_centrality', 'CentralityCosDist_rank',
#        'CentralityCosDist_similarity_score', 'has_verified_sequence',
#        'sequence', 'UniProtKB-AC', 'ID', 'mask', 'DeepTMHMM_trimmed_sequence',
#        'DeepTMHMM_class', 'cleavage_site_start', 'signalP_trimmed_sequence'],
#       dtype='object')

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3927 entries, 0 to 3926
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   node                                3927 non-null   object
#  1   _wkshell                            3927 non-null   int64
#  2   degree_centrality                   3927 non-null   float64
#  3   betweenness_centrality              3927 non-null   float64
#  4   eigenvector_centrality              3927 non-null   float64
#  5   closeness_centrality                3927 non-null   float64
#  6   load_centrality                     3927 non-null   float64
#  7   pagerank                            3927 non-null   float64
#  8   information_centrality              3927 non-null   float64
#  9   CentralityCosDist_rank              3927 non-null   float64
#  10  CentralityCosDist_similarity_score  3927 non-null   float64
#  11  has_verified_sequence               3927 non-null   bool
#  12  sequence                            3876 non-null   object
#  13  UniProtKB-AC                        3885 non-null   object
#  14  ID                                  3885 non-null   object
#  15  mask                                3876 non-null   object
#  16  DeepTMHMM_trimmed_sequence          3875 non-null   object
#  17  DeepTMHMM_class                     3876 non-null   object
#  18  cleavage_site_start                 129 non-null    float64
#  19  signalP_trimmed_sequence            3876 non-null   object
# dtypes: bool(1), float64(10), int64(1), object(8)
# memory usage: 586.9+ KB

# %%
data4 = pd.read_pickle("../../4-idr-properties/processed-data/0-s288c-nodes-centrality-seqs-DeepTMHMM-SignalP-UniProt-IDRs-albatross-cider.pkl")

# %%
data4.columns
# Out:
# Index(['node', '_wkshell', 'degree_centrality', 'betweenness_centrality',
#        'eigenvector_centrality', 'closeness_centrality', 'load_centrality',
#        'pagerank', 'information_centrality', 'CentralityCosDist_rank',
#        'CentralityCosDist_similarity_score', 'has_verified_sequence',
#        'sequence', 'UniProtKB-AC', 'ID', 'mask', 'DeepTMHMM_trimmed_sequence',
#        'DeepTMHMM_class', 'cleavage_site_start', 'signalP_trimmed_sequence',
#        'ProteinName', 'GO_terms', 'localization_keywords', 'parsed_functions',
#        'parsed_PTMs', 'disorder_predictions', 'disorder_fraction',
#        'is_disordered_0.05', 'is_disordered_0.10', 'is_disordered_0.15',
#        'is_disordered_0.20', 'is_disordered_0.25', 'is_disordered_0.30',
#        'is_disordered_0.35', 'is_disordered_0.40', 'is_disordered_0.45',
#        'is_disordered_0.50', 'is_disordered_0.55', 'is_disordered_0.60',
#        'is_disordered_0.65', 'is_disordered_0.70', 'is_disordered_0.75',
#        'is_disordered_0.80', 'is_disordered_0.85', 'is_disordered_0.90',
#        'is_disordered_0.95', 'is_disordered_1.00', 'IDR_count',
#        'IDR_sequences', 'albatross', 'cider'],
#       dtype='object')

# %%
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3927 entries, 0 to 3926
# Data columns (total 51 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   node                                3927 non-null   object
#  1   _wkshell                            3927 non-null   int64
#  2   degree_centrality                   3927 non-null   float64
#  3   betweenness_centrality              3927 non-null   float64
#  4   eigenvector_centrality              3927 non-null   float64
#  5   closeness_centrality                3927 non-null   float64
#  6   load_centrality                     3927 non-null   float64
#  7   pagerank                            3927 non-null   float64
#  8   information_centrality              3927 non-null   float64
#  9   CentralityCosDist_rank              3927 non-null   float64
#  10  CentralityCosDist_similarity_score  3927 non-null   float64
#  11  has_verified_sequence               3927 non-null   bool
#  12  sequence                            3876 non-null   object
#  13  UniProtKB-AC                        3885 non-null   object
#  14  ID                                  3885 non-null   object
#  15  mask                                3876 non-null   object
#  16  DeepTMHMM_trimmed_sequence          3875 non-null   object
#  17  DeepTMHMM_class                     3876 non-null   object
#  18  cleavage_site_start                 129 non-null    float64
#  19  signalP_trimmed_sequence            3876 non-null   object
#  20  ProteinName                         3885 non-null   object
#  21  GO_terms                            3885 non-null   object
#  22  localization_keywords               3885 non-null   object
#  23  parsed_functions                    3885 non-null   object
#  24  parsed_PTMs                         3885 non-null   object
#  25  disorder_predictions                3876 non-null   object
#  26  disorder_fraction                   3876 non-null   float64
#  27  is_disordered_0.05                  3927 non-null   int64
#  28  is_disordered_0.10                  3927 non-null   int64
#  29  is_disordered_0.15                  3927 non-null   int64
#  30  is_disordered_0.20                  3927 non-null   int64
#  31  is_disordered_0.25                  3927 non-null   int64
#  32  is_disordered_0.30                  3927 non-null   int64
#  33  is_disordered_0.35                  3927 non-null   int64
#  34  is_disordered_0.40                  3927 non-null   int64
#  35  is_disordered_0.45                  3927 non-null   int64
#  36  is_disordered_0.50                  3927 non-null   int64
#  37  is_disordered_0.55                  3927 non-null   int64
#  38  is_disordered_0.60                  3927 non-null   int64
#  39  is_disordered_0.65                  3927 non-null   int64
#  40  is_disordered_0.70                  3927 non-null   int64
#  41  is_disordered_0.75                  3927 non-null   int64
#  42  is_disordered_0.80                  3927 non-null   int64
#  43  is_disordered_0.85                  3927 non-null   int64
#  44  is_disordered_0.90                  3927 non-null   int64
#  45  is_disordered_0.95                  3927 non-null   int64
#  46  is_disordered_1.00                  3927 non-null   int64
#  47  IDR_count                           3927 non-null   int64
#  48  IDR_sequences                       3876 non-null   object
#  49  albatross                           2508 non-null   object
#  50  cider                               2508 non-null   object
# dtypes: bool(1), float64(11), int64(22), object(17)
# memory usage: 1.5+ MB

# %%
data5 = pd.read_pickle("../../5-dG-calculations/processed-data/0-s288c-nodes-centrality-seqs-DeepTMHMM-SignalP-UniProt-IDRs-albatross-cider-GhoshDill-Cagiada.pkl")

# %%
data5.columns
# Out:
# Index(['node', '_wkshell', 'degree_centrality', 'betweenness_centrality',
#        'eigenvector_centrality', 'closeness_centrality', 'load_centrality',
#        'pagerank', 'information_centrality', 'CentralityCosDist_rank',
#        'CentralityCosDist_similarity_score', 'has_verified_sequence',
#        'sequence', 'UniProtKB-AC', 'ID', 'mask', 'DeepTMHMM_trimmed_sequence',
#        'DeepTMHMM_class', 'cleavage_site_start', 'signalP_trimmed_sequence_x',
#        'ProteinName', 'GO_terms', 'localization_keywords', 'parsed_functions',
#        'parsed_PTMs', 'disorder_predictions', 'disorder_fraction',
#        'is_disordered_0.05', 'is_disordered_0.10', 'is_disordered_0.15',
#        'is_disordered_0.20', 'is_disordered_0.25', 'is_disordered_0.30',
#        'is_disordered_0.35', 'is_disordered_0.40', 'is_disordered_0.45',
#        'is_disordered_0.50', 'is_disordered_0.55', 'is_disordered_0.60',
#        'is_disordered_0.65', 'is_disordered_0.70', 'is_disordered_0.75',
#        'is_disordered_0.80', 'is_disordered_0.85', 'is_disordered_0.90',
#        'is_disordered_0.95', 'is_disordered_1.00', 'IDR_count',
#        'IDR_sequences', 'albatross', 'cider', 'structure_path',
#        'structure_exists', 'structure_fasta_path', 'structure_sequence',
#        'cleaved_structure_path', 'cleaved_structure_sequence',
#        'sequence_matches_structure', 'signalP_trimmed_sequence_y', 'L', 'dH',
#        'dCp', 'dS', 'Ghosh-Dill-dG', 'cagiada-dG'],
#       dtype='object')

# %%
row = data5[data5["node"] == "YKL063C"]
row.columns
print(row["L"])
# Out:
# 0   NaN
# Name: L, dtype: float64

# %%
data5 = pd.read_pickle("../../5-dG-calculations/processed-data/0-s288c-nodes-centrality-seqs-DeepTMHMM-SignalP-UniProt-IDRs-albatross-cider-GhoshDill.pkl")
row = data5[data5["node"] == "YKL063C"]
row.columns
print(row["L"])
# Out:
# 0   NaN
# Name: L, dtype: float64

# %%
data5.columns
# Out:
# Index(['node', '_wkshell', 'degree_centrality', 'betweenness_centrality',
#        'eigenvector_centrality', 'closeness_centrality', 'load_centrality',
#        'pagerank', 'information_centrality', 'CentralityCosDist_rank',
#        'CentralityCosDist_similarity_score', 'has_verified_sequence',
#        'sequence', 'UniProtKB-AC', 'ID', 'mask', 'DeepTMHMM_trimmed_sequence',
#        'DeepTMHMM_class', 'cleavage_site_start', 'signalP_trimmed_sequence_x',
#        'ProteinName', 'GO_terms', 'localization_keywords', 'parsed_functions',
#        'parsed_PTMs', 'disorder_predictions', 'disorder_fraction',
#        'is_disordered_0.05', 'is_disordered_0.10', 'is_disordered_0.15',
#        'is_disordered_0.20', 'is_disordered_0.25', 'is_disordered_0.30',
#        'is_disordered_0.35', 'is_disordered_0.40', 'is_disordered_0.45',
#        'is_disordered_0.50', 'is_disordered_0.55', 'is_disordered_0.60',
#        'is_disordered_0.65', 'is_disordered_0.70', 'is_disordered_0.75',
#        'is_disordered_0.80', 'is_disordered_0.85', 'is_disordered_0.90',
#        'is_disordered_0.95', 'is_disordered_1.00', 'IDR_count',
#        'IDR_sequences', 'albatross', 'cider', 'structure_path',
#        'structure_exists', 'structure_fasta_path', 'structure_sequence',
#        'cleaved_structure_path', 'cleaved_structure_sequence',
#        'sequence_matches_structure', 'signalP_trimmed_sequence_y', 'L', 'dH',
#        'dCp', 'dS', 'Ghosh-Dill-dG', 'cagiada-dG'],
#       dtype='object')

# %%
data5 = pd.read_pickle("../../5-dG-calculations/processed-data/0-s288c-temp.pkl")

# %%
data5.columns
# Out:
# Index(['node', '_wkshell', 'degree_centrality', 'betweenness_centrality',
#        'eigenvector_centrality', 'closeness_centrality', 'load_centrality',
#        'pagerank', 'information_centrality', 'CentralityCosDist_rank',
#        'CentralityCosDist_similarity_score', 'has_verified_sequence',
#        'sequence', 'UniProtKB-AC', 'ID', 'mask', 'DeepTMHMM_trimmed_sequence',
#        'DeepTMHMM_class', 'cleavage_site_start', 'signalP_trimmed_sequence',
#        'ProteinName', 'GO_terms', 'localization_keywords', 'parsed_functions',
#        'parsed_PTMs', 'disorder_predictions', 'disorder_fraction',
#        'is_disordered_0.05', 'is_disordered_0.10', 'is_disordered_0.15',
#        'is_disordered_0.20', 'is_disordered_0.25', 'is_disordered_0.30',
#        'is_disordered_0.35', 'is_disordered_0.40', 'is_disordered_0.45',
#        'is_disordered_0.50', 'is_disordered_0.55', 'is_disordered_0.60',
#        'is_disordered_0.65', 'is_disordered_0.70', 'is_disordered_0.75',
#        'is_disordered_0.80', 'is_disordered_0.85', 'is_disordered_0.90',
#        'is_disordered_0.95', 'is_disordered_1.00', 'IDR_count',
#        'IDR_sequences', 'albatross', 'cider', 'structure_path',
#        'structure_exists', 'structure_fasta_path', 'structure_sequence',
#        'cleaved_structure_path', 'cleaved_structure_sequence',
#        'sequence_matches_structure'],
#       dtype='object')

# %%
final = pd.read_csv("../../flatten/processed-data/0-s288c-nodes-final-per-node.csv")
random_sample = final.sample(n=15, random_state=42)

# %%
columns_to_print = [
    "node",
    "UniProtKB-AC",
    "ProteinName",
    "GO_terms",
    "localization_keywords",
    "parsed_functions",
    "parsed_PTMs"
]

for _, row in random_sample.iterrows():
    print({col: row[col] for col in columns_to_print})
# Out:
# {'node': 'YOL076W', 'UniProtKB-AC': 'Q12387', 'ProteinName': 'RecName: Full=N-terminal acetyltransferase B complex subunit MDM20; Short=NatB complex subunit MDM20; AltName: Full=Dislikes extra CIN8 protein 1; AltName: Full=Mitochondrial distribution and morphology protein 20;', 'GO_terms': "['C:cytoplasm', 'C:NatB complex', 'F:acetyltransferase activator activity', 'P:cytoskeleton organization', 'P:mitochondrion inheritance', 'P:regulation of actin cytoskeleton organization']", 'localization_keywords': "['Cytoplasm']", 'parsed_functions': "['Non-catalytic subunit of the NatB N-terminal acetyltransferase, which catalyzes acetylation of the amino-terminal methionine residues of all proteins beginning with Met-Asp or Met-Glu and of some proteins beginning with Met-Asn or Met-Met. NatB acetylates TPM1 protein and regulates tropomyocin-actin interactions. MDM20 is required for mitochondrial inheritance during budding and together with TPM1, is essential for the integrity and assembly of actin cables. Genetically interacts with CIN8. ']", 'parsed_PTMs': '[]'}
# {'node': 'YGR157W', 'UniProtKB-AC': 'P05374', 'ProteinName': 'RecName: Full=Phosphatidylethanolamine N-methyltransferase {ECO:0000255|HAMAP-Rule:MF_03217, ECO:0000303|PubMed:2445736}; Short=PE methyltransferase {ECO:0000255|HAMAP-Rule:MF_03217, ECO:0000303|PubMed:2445736}; Short=PEAMT {ECO:0000255|HAMAP-Rule:MF_03217}; Short=PEMT {ECO:0000255|HAMAP-Rule:MF_03217, ECO:0000303|PubMed:1954254}; EC=2.1.1.17 {ECO:0000255|HAMAP-Rule:MF_03217, ECO:0000269|PubMed:2198947, ECO:0000269|PubMed:22001639, ECO:0000269|PubMed:2445736, ECO:0000269|PubMed:2684666}; AltName: Full=Choline-requiring protein 2 {ECO:0000305|PubMed:3066687};', 'GO_terms': "['C:cell periphery', 'C:endoplasmic reticulum', 'C:endoplasmic reticulum membrane', 'F:phosphatidylethanolamine N-methyltransferase activity', 'P:methylation', 'P:phosphatidylcholine biosynthetic process']", 'localization_keywords': "['Endoplasmic reticulum membrane', 'Multi- pass membrane protein']", 'parsed_functions': "['Catalyzes the first step of the methylation pathway of phosphatidylcholine biosynthesis, the SAM-dependent methylation of phosphatidylethanolamine (PE) to phosphatidylmonomethylethanolamine (PMME). Preferentially converts di-C16:1 substrates. ']", 'parsed_PTMs': '[]'}
# {'node': 'YNL119W', 'UniProtKB-AC': 'P53923', 'ProteinName': 'RecName: Full=Cytoplasmic tRNA 2-thiolation protein 2 {ECO:0000255|HAMAP-Rule:MF_03054}; AltName: Full=Needs CLA4 to survive protein 2 {ECO:0000255|HAMAP-Rule:MF_03054}; AltName: Full=Thiolation of uridine in cytoplasmic tRNA protein 2 {ECO:0000255|HAMAP-Rule:MF_03054};', 'GO_terms': "['C:cytoplasm', 'C:cytosol', 'F:nucleotidyltransferase activity', 'F:sulfurtransferase activity', 'F:tRNA binding', 'P:invasive growth in response to glucose limitation', 'P:protein urmylation', 'P:pseudohyphal growth', 'P:tRNA thio-modification', 'P:tRNA wobble position uridine thiolation', 'P:tRNA wobble uridine modification']", 'localization_keywords': "['Cytoplasm']", 'parsed_functions': "['Plays a central role in 2-thiolation of mcm(5)S(2)U at tRNA wobble positions of tRNA(Lys), tRNA(Glu) and tRNA(Gln). May act by forming a heterodimer with NCS6 that ligates sulfur from thiocarboxylated URM1 onto the uridine of tRNAs at wobble position. Prior mcm(5) tRNA modification by the elongator complex is required for 2-thiolation. May also be involved in protein urmylation and in invasive and pseudohyphal growth. Inhibits replication of Brome mosaic virus. . PATHWAY: tRNA modification; 5-methoxycarbonylmethyl-2-thiouridine-tRNA biosynthesis. ']", 'parsed_PTMs': '[]'}
# {'node': 'YKR058W', 'UniProtKB-AC': 'P36143', 'ProteinName': 'RecName: Full=Glycogenin-1 {ECO:0000303|PubMed:8524228}; EC=2.4.1.186 {ECO:0000269|PubMed:8524228}; AltName: Full=Glycogen synthesis initiator protein 1 {ECO:0000303|PubMed:8524228}; AltName: Full=Glycogenin glucosyltransferase 1 {ECO:0000303|PubMed:8524228};', 'GO_terms': "['C:cytoplasm', 'C:vacuole', 'F:glycogenin glucosyltransferase activity', 'F:glycosyltransferase activity', 'F:metal ion binding', 'P:glycogen biosynthetic process']", 'localization_keywords': "['Cytoplasm', 'Vacuole']", 'parsed_functions': "['Self-glucosylating initiator of glycogen synthesis. It catalyzes the formation of a short alpha (1,4)-glucosyl chain covalently attached via a glucose 1-O-tyrosyl linkage to internal tyrosine residues and these chains act as primers for the elongation reaction catalyzed by glycogen synthase. Capable of transferring glucosyl residues to unbound acceptors such as free oligoglucans or oligoglucan derivatives. ']", 'parsed_PTMs': '[]'}
# {'node': 'YKL090W', 'UniProtKB-AC': 'P36075', 'ProteinName': 'RecName: Full=Endonuclease CUE2 {ECO:0000305}; AltName: Full=Coupling of ubiquitin conjugation to ER degradation protein 2;', 'GO_terms': "['C:cytosolic ribosome', 'F:endonuclease activity', 'F:K63-linked polyubiquitin modification-dependent protein binding', 'F:polyubiquitin modification-dependent protein binding', 'F:RNA endonuclease activity', 'F:ubiquitin binding', 'P:nuclear-transcribed mRNA catabolic process, no-go decay', 'P:rescue of stalled ribosome']", 'localization_keywords': '[]', 'parsed_functions': "['mRNA endonuclease involved in the No-Go Decay (NGD) pathway, which catalyzes mRNA cleavage and degradation in response to ribosome collisions (PubMed:31219035, PubMed:36583309). Acts downstream of the ribosome collision sensor HEL2 (PubMed:36583309). Specifically recognizes and binds RPS7/eS7 polyubiquitinated by MOT2/NOT4 and HEL2, promoting CUE2 recruitment to stalled ribosomes, where it mediates mRNA cleavage upstream of the colliding ribosome (PubMed:36583309). Also mediates mRNA cleavage within colliding ribosomes: recruited to colliding ribosomes downstream of the RQT (ribosome quality control trigger) complex following disassembly of stalled ribosomes and cleaves mRNAs partially released from the colliding ribosome (PubMed:36583309). ']", 'parsed_PTMs': '[]'}
# {'node': 'YOR229W', 'UniProtKB-AC': 'Q12206', 'ProteinName': 'RecName: Full=Transcriptional modulator WTM2;', 'GO_terms': "['C:cytoplasm', 'C:cytosol', 'C:nucleus', 'C:Rpd3L complex', 'C:Rpd3L-Expanded complex', 'F:DNA-binding transcription factor activity, RNA polymerase II-specific', 'F:histone binding', 'F:transcription corepressor activity', 'P:chromatin remodeling', 'P:DNA damage response', 'P:meiotic cell cycle', 'P:negative regulation of silent mating-type cassette heterochromatin formation', 'P:negative regulation of transcription by RNA polymerase II', 'P:positive regulation of transcription by RNA polymerase II', 'P:protein-containing complex localization', 'P:regulation of DNA-templated transcription']", 'localization_keywords': '[]', 'parsed_functions': "['Transcriptional modulator with roles in meiotic regulation and silencing. INTERACTION: Q12206; P49723: RNR4; NbExp=3; IntAct=EBI-20571, EBI-15251; Q12206; Q12363: WTM1; NbExp=4; IntAct=EBI-20571, EBI-20563; Q12206; Q12040: YOR283W; NbExp=3; IntAct=EBI-20571, EBI-31025;']", 'parsed_PTMs': '[]'}
# {'node': 'YOR085W', 'UniProtKB-AC': 'P48439', 'ProteinName': 'RecName: Full=Dolichyl-diphosphooligosaccharide--protein glycosyltransferase subunit 3; AltName: Full=Oligosaccharyl transferase 34 kDa subunit; AltName: Full=Oligosaccharyl transferase subunit OST3; AltName: Full=Oligosaccharyl transferase subunit gamma; Flags: Precursor;', 'GO_terms': "['C:endoplasmic reticulum', 'C:endoplasmic reticulum membrane', 'C:membrane', 'C:oligosaccharyltransferase complex', 'F:dolichyl-diphosphooligosaccharide-protein glycotransferase activity', 'F:protein-disulfide reductase activity', 'P:protein glycosylation', 'P:protein N-linked glycosylation', 'P:protein N-linked glycosylation via asparagine', 'P:protein O-linked mannosylation']", 'localization_keywords': "['Endoplasmic reticulum membrane', 'Multi-pass membrane protein']", 'parsed_functions': "['Subunit of the oligosaccharyl transferase (OST) complex that catalyzes the initial transfer of a defined glycan (Glc(3)Man(9)GlcNAc(2) in eukaryotes) from the lipid carrier dolichol- pyrophosphate to an asparagine residue within an Asn-X-Ser/Thr consensus motif in nascent polypeptide chains, the first step in protein N-glycosylation. N-glycosylation occurs cotranslationally and the complex associates with the Sec61 complex at the channel-forming translocon complex that mediates protein translocation across the endoplasmic reticulum (ER). All subunits are required for a maximal enzyme activity. . PATHWAY: Protein modification; protein glycosylation. ']", 'parsed_PTMs': '[]'}
# {'node': 'YBR088C', 'UniProtKB-AC': 'P15873', 'ProteinName': 'RecName: Full=Proliferating cell nuclear antigen; Short=PCNA;', 'GO_terms': "['C:chromosome, telomeric region', 'C:nucleus', 'C:PCNA complex', 'C:replication fork', 'F:DNA binding', 'F:DNA polymerase processivity factor activity', 'F:identical protein binding', 'P:error-free translesion synthesis', 'P:establishment of mitotic sister chromatid cohesion', 'P:lagging strand elongation', 'P:leading strand elongation', 'P:maintenance of DNA trinucleotide repeats', 'P:meiotic mismatch repair', 'P:mismatch repair', 'P:mitotic cell cycle', 'P:mitotic sister chromatid cohesion', 'P:nucleotide-excision repair', 'P:positive regulation of DNA metabolic process', 'P:positive regulation of DNA repair', 'P:positive regulation of DNA replication', 'P:postreplication repair', 'P:silent mating-type cassette heterochromatin formation', 'P:subtelomeric heterochromatin formation', 'P:translesion synthesis']", 'localization_keywords': "['Nucleus']", 'parsed_functions': '["This protein is an auxiliary protein of DNA polymerase delta and is involved in the control of eukaryotic DNA replication by increasing the polymerase\'s processibility during elongation of the leading strand. Involved in DNA repair. "]', 'parsed_PTMs': '[\'Sumoylated on Lys-164, and to a lesser extent on Lys-127 by the UBC9/SIZ1 complex during S-phase; which impairs ubiquitination and function in DNA repair. \', "Monoubiquitinated on Lys-164 by the UBC2/RAD18 complex upon DNA damage, and then polyubiquitinated through \'Lys-63\'-linkage by UBC13/MMS2. Ubiquitination is required for UBC2-mediated DNA repair. ", \'Lys-164 is deubiquitinated by UBP10 (PubMed:22829782). \']'}
# {'node': 'YGL253W', 'UniProtKB-AC': 'P04807', 'ProteinName': 'RecName: Full=Hexokinase-2; EC=2.7.1.1 {ECO:0000305|PubMed:332086}; AltName: Full=Hexokinase PII; AltName: Full=Hexokinase-B;', 'GO_terms': "['C:cytosol', 'C:mitochondrial membrane', 'C:mitochondrion', 'C:nucleus', 'F:ATP binding', 'F:D-glucose binding', 'F:fructokinase activity', 'F:glucokinase activity', 'F:hexokinase activity', 'F:mannokinase activity', 'P:D-glucose import', 'P:fructose import across plasma membrane', 'P:fructose metabolic process', 'P:glucose 6-phosphate metabolic process', 'P:glucose metabolic process', 'P:glycolytic process', 'P:intracellular glucose homeostasis', 'P:mannose metabolic process', 'P:negative regulation of apoptotic signaling pathway', 'P:regulation of cell size', 'P:regulation of transcription by glucose']", 'localization_keywords': '[]', 'parsed_functions': "['Catalyzes the phosphorylation of hexose, such as D-glucose and D-fructose, to hexose 6-phosphate (D-glucose 6-phosphate and D- fructose 6-phosphate, respectively) (PubMed:332086). Mediates the initial step of glycolysis by catalyzing phosphorylation of D-glucose to D-glucose 6-phosphate (PubMed:332086). ']", 'parsed_PTMs': '[]'}
# {'node': 'YDL112W', 'UniProtKB-AC': 'Q07527', 'ProteinName': "RecName: Full=tRNA (guanosine(18)-2'-O)-methyltransferase {ECO:0000305|PubMed:9917067}; EC=2.1.1.34 {ECO:0000269|PubMed:9917067}; AltName: Full=tRNA [Gm18] ribose methylase {ECO:0000303|PubMed:9917067}; AltName: Full=tRNA methyltransferase 3 {ECO:0000303|PubMed:9917067};", 'GO_terms': '[\'C:cytoplasm\', \'F:RNA binding\', "F:tRNA (guanine(18)-2\'-O)-methyltransferase activity", \'F:tRNA (guanine) methyltransferase activity\', \'P:cellular response to oxidative stress\', \'P:tRNA methylation\', \'P:tRNA nucleoside ribose methylation\']', 'localization_keywords': "['Cytoplasm']", 'parsed_functions': '["S-adenosyl-L-methionine-dependent 2\'-O-ribose methyltransferase that catalyzes the formation of 2\'-O-methylguanosine at position 18 (Gm18) in various tRNAs. "]', 'parsed_PTMs': '[]'}
# {'node': 'YER100W', 'UniProtKB-AC': 'P33296', 'ProteinName': 'RecName: Full=Ubiquitin-conjugating enzyme E2 6; EC=2.3.2.23; AltName: Full=E2 ubiquitin-conjugating enzyme 6; AltName: Full=Ubiquitin carrier protein UBC6; AltName: Full=Ubiquitin-protein ligase UBC6;', 'GO_terms': "['C:endoplasmic reticulum', 'C:endoplasmic reticulum membrane', 'C:nucleus', 'F:ATP binding', 'F:ubiquitin conjugating enzyme activity', 'F:ubiquitin-protein transferase activity', 'P:ERAD pathway', 'P:protein monoubiquitination', 'P:protein polyubiquitination']", 'localization_keywords': "['Endoplasmic reticulum membrane']", 'parsed_functions': "['Catalyzes the covalent attachment of ubiquitin to other proteins. Functions in degradation of misfolded or regulated proteins localized in the endoplasmic reticulum (ER) lumen or membrane via the ubiquitin-proteasome system. Cognate E2 conjugating enzyme for the DOA10 ubiquitin ligase complex, which is part of the ERAD-C pathway responsible for the rapid degradation of membrane proteins with misfolded cytoplasmic domains. ']", 'parsed_PTMs': '[]'}
# {'node': 'YIL096C', 'UniProtKB-AC': 'P40493', 'ProteinName': 'RecName: Full=25S rRNA (uridine(2634)-N(3))-methyltransferase; EC=2.1.1.313 {ECO:0000269|PubMed:24335083}; AltName: Full=Base methyltransferase of 25S RNA 5;', 'GO_terms': "['C:cytoplasm', 'C:nucleolus', 'C:nucleus', 'F:rRNA (uridine-N3-)-methyltransferase activity', 'F:S-adenosylmethionine-dependent methyltransferase activity', 'P:rRNA base methylation']", 'localization_keywords': "['Nucleus, nucleolus']", 'parsed_functions': "['S-adenosyl-L-methionine-dependent methyltransferase that specifically methylates the N(3) position of uridine 2634 (m3U2634) in 25S rRNA. ']", 'parsed_PTMs': '[]'}
# {'node': 'YDR334W', 'UniProtKB-AC': 'Q05471', 'ProteinName': 'RecName: Full=Helicase SWR1; EC=3.6.4.12; AltName: Full=Swi2/Snf2-related 1;', 'GO_terms': '[\'C:chromatin\', \'C:cytosol\', \'C:nucleus\', \'C:Swr1 complex\', \'F:ATP binding\', \'F:ATP hydrolysis activity\', \'F:DNA binding\', \'F:double-stranded DNA helicase activity\', \'F:forked DNA-dependent helicase activity\', \'F:four-way junction helicase activity\', \'F:histone binding\', \'F:molecular adaptor activity\', "F:single-stranded 3\'-5\' DNA helicase activity", \'F:structural molecule activity\', \'P:chromatin remodeling\', \'P:recombinational repair\', \'P:regulation of DNA-templated transcription\']', 'localization_keywords': "['Nucleus']", 'parsed_functions': "['Catalytic component of the SWR1 complex which mediates the ATP-dependent exchange of histone H2A for the H2A variant HZT1 leading to transcriptional regulation of selected genes by chromatin remodeling. ']", 'parsed_PTMs': '[]'}
# {'node': 'YDR004W', 'UniProtKB-AC': 'P25301', 'ProteinName': 'RecName: Full=DNA repair protein RAD57;', 'GO_terms': "['C:Rad51C-XRCC3 complex', 'F:ATP binding', 'F:ATP hydrolysis activity', 'F:ATP-dependent activity, acting on DNA', 'F:ATP-dependent DNA damage sensor activity', 'F:DNA strand exchange activity', 'F:double-stranded DNA binding', 'F:single-stranded DNA binding', 'P:DNA recombinase assembly', 'P:DNA strand invasion', 'P:double-strand break repair', 'P:error-free postreplication DNA repair', 'P:heteroduplex formation', 'P:meiotic DNA recombinase assembly', 'P:mitotic recombination', 'P:positive regulation of single-strand break repair via homologous recombination', 'P:telomere maintenance via recombination']", 'localization_keywords': "['Nucleus']", 'parsed_functions': "['Participates in the repair of X-ray-induced damage to DNA and in meiosis. It may act in part by stabilizing a repair complex of other RAD genes. INTERACTION: P25301; Q06032: CST9; NbExp=2; IntAct=EBI-14744, EBI-30044; P25301; P38953: RAD55; NbExp=10; IntAct=EBI-14744, EBI-14737;']", 'parsed_PTMs': '[]'}
# {'node': 'YML095C', 'UniProtKB-AC': 'P06838', 'ProteinName': 'RecName: Full=DNA repair protein RAD10;', 'GO_terms': "['C:endonuclease complex', 'C:nucleotide-excision repair factor 1 complex', 'C:nucleus', 'F:damaged DNA binding', 'F:endonuclease activity', 'F:single-stranded DNA binding', 'P:DNA amplification', 'P:double-strand break repair via single-strand annealing, removal of nonhomologous ends', 'P:meiotic mismatch repair', 'P:mitotic recombination', 'P:nucleotide-excision repair', 'P:nucleotide-excision repair, DNA damage recognition', 'P:removal of nonhomologous ends']", 'localization_keywords': "['Nucleus']", 'parsed_functions': "['Involved in nucleotide excision repair of DNA damaged with UV light, bulky adducts, or cross-linking agents. Along with RAD1 forms an endonuclease that specifically degrades single-stranded DNA. ']", 'parsed_PTMs': '[]'}
