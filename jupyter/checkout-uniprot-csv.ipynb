# %%
import pandas as pd

# %%
df = pd.read_csv("../processed-data/uniprot_sprot-s288c.csv")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6733 entries, 0 to 6732
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   EntryName              6733 non-null   object
#  1   PrimaryAccession       6733 non-null   object
#  2   AllAccessions          6733 non-null   object
#  3   GeneName               6733 non-null   object
#  4   ProteinName            6733 non-null   object
#  5   Organism               6733 non-null   object
#  6   SequenceLength         6733 non-null   int64
#  7   Sequence               6733 non-null   object
#  8   GO_terms               6733 non-null   object
#  9   CrossReferences        6733 non-null   object
#  10  Localization           6733 non-null   object
#  11  localization_keywords  6733 non-null   object
#  12  Function               6733 non-null   object
#  13  parsed_functions       6733 non-null   object
# ...

# %%
print(df.loc[0, "PTMs"])
df["PTMs"]
# Out:
# []
# 0       []
# 1       []
# 2       []
# 3       []
# 4       []
#         ..
# 6728    []
# 6729    []
# 6730    []
# 6731    []
# 6732    []
# Name: PTMs, Length: 6733, dtype: object

# %%
print(df.loc[0, "Localization"])  # Or use .iloc[0]
print(df.loc[0, "localization_keywords"])

# %%
print(df.loc[19, "Localization"])  # Or use .iloc[0]
print(df.loc[19, "localization_keywords"])

# %%
df["Localization"].head(20)

# %%
df["localization_keywords", "Localization"].head(20)

# %%
df["PrimaryAccession"].head(20)

# %%
print(df.loc[16, "localization_keywords"])

# %%
print(df.loc[0, "Function"])  # Or use .iloc[0]

# %%
print(df.loc[0, "parsed_functions"])  # Or use .iloc[0]

# %%
df["Function"]

# %%
df["parsed_functions"]

# %%
df[["PrimaryAccession", "localization_keywords", "Localization", "PTMs", "parsed_PTMs"]].to_csv("../processed-data/output.csv", index=False)

# %%
print(df.loc[68, "Localization"])  # Or use .iloc[0]
print(df.loc[68, "localization_keywords"])

# %%
print(df.loc[5531, "Localization"])  # Or use .iloc[0]
print(df.loc[5531, "localization_keywords"])

# %%
df["GO_terms"].head(20)

# %%
print(df.loc[68, "GO_terms"])  # Or use .iloc[0]
#print(df.loc[68, "localization_keywords"])
